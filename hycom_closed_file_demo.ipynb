# %%
# !mkdir zarr_build

# %%
from hycom_recipe import recipes as recipe_dict
from recipe_helpers import setup_logging, setup_targets

setup_logging()
rec = setup_targets(recipe_dict, key="HYCOM50/Region02_GE/int/fma")
# Out:
# Targets for recipe_dict["HYCOM50/Region02_GE/int/fma"] set to:
#
#     input_cache: gs://pangeo-forge-us-central1/pangeo-forge-cache/swot_adac/HYCOM50/Region02_GE/int/fma
#     metadata_cache: metadata/HYCOM50-Region02_GE-int-fma
#     target: zarr_build/HYCOM50-Region02_GE-int-fma.zarr

# %%
rec.prepare_target()
# Out:
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Creating a new dataset in target
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening inputs for chunk (0,)
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray (0,): 'ftp://ftp.hycom.org/pub/xbxu/ATLc0.02/SWOT_ADAC/HYCOM50_E043_Feb_GE_daily.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'ftp://ftp.hycom.org/pub/xbxu/ATLc0.02/SWOT_ADAC/HYCOM50_E043_Feb_GE_daily.nc' from cache
# pangeo_forge_recipes.storage - DEBUG - file_opener entering first context for <contextlib._GeneratorContextManager object at 0x7f33490f4670>
# pangeo_forge_recipes.storage - DEBUG - entering fs.open context manager for gs://pangeo-forge-us-central1/pangeo-forge-cache/swot_adac/HYCOM50/Region02_GE/int/fma/df4955281e33c8c39ad42fca01b0f13b-ftp_ftp.hycom.org_pub_xbxu_atlc0.02_swot_adac_hycom50_e043_feb_ge_daily.nc
# ...

# %% [markdown]
# #### Start `store_chunk`, then `KeyboardInterrupt` to simulate some unknown interruption

# %%
for chunk in rec.iter_chunks():
    rec.store_chunk(chunk)
# Out:
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening inputs for chunk (0,)
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray (0,): 'ftp://ftp.hycom.org/pub/xbxu/ATLc0.02/SWOT_ADAC/HYCOM50_E043_Feb_GE_daily.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'ftp://ftp.hycom.org/pub/xbxu/ATLc0.02/SWOT_ADAC/HYCOM50_E043_Feb_GE_daily.nc' from cache
# pangeo_forge_recipes.storage - DEBUG - file_opener entering first context for <contextlib._GeneratorContextManager object at 0x7f33490dcd90>
# pangeo_forge_recipes.storage - DEBUG - entering fs.open context manager for gs://pangeo-forge-us-central1/pangeo-forge-cache/swot_adac/HYCOM50/Region02_GE/int/fma/df4955281e33c8c39ad42fca01b0f13b-ftp_ftp.hycom.org_pub_xbxu_atlc0.02_swot_adac_hycom50_e043_feb_ge_daily.nc
# ...

# %% [markdown]
# #### Resuming `store_chunk` raises `ValueError: I/O operation on closed file.`
#
# Note that despite this error, the print of `f.closed` I added [here](https://github.com/cisaacstern/pangeo-forge-recipes/blob/50e56c998ca569f91c130797eb6011b3690c03c6/pangeo_forge_recipes/recipes/xarray_zarr.py#L206-L208) doesn't register the chunk as closed, returning instead:
#
#     (0.4.0) In `xarray_zarr.open_input` line 207, the value of `f.closed` is False

# %%
for chunk in rec.iter_chunks():
    rec.store_chunk(chunk)
# Out:
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening inputs for chunk (0,)
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray (0,): 'ftp://ftp.hycom.org/pub/xbxu/ATLc0.02/SWOT_ADAC/HYCOM50_E043_Feb_GE_daily.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'ftp://ftp.hycom.org/pub/xbxu/ATLc0.02/SWOT_ADAC/HYCOM50_E043_Feb_GE_daily.nc' from cache
# pangeo_forge_recipes.storage - DEBUG - file_opener entering first context for <contextlib._GeneratorContextManager object at 0x7f334889bb20>
# pangeo_forge_recipes.storage - DEBUG - entering fs.open context manager for gs://pangeo-forge-us-central1/pangeo-forge-cache/swot_adac/HYCOM50/Region02_GE/int/fma/df4955281e33c8c39ad42fca01b0f13b-ftp_ftp.hycom.org_pub_xbxu_atlc0.02_swot_adac_hycom50_e043_feb_ge_daily.nc
# ...

# %% [markdown]
# #### Restarting from `prepare_target` also raises `ValueError: I/O operation on closed file.`

# %%
# !rm -r zarr_build/*

# %%
rec.prepare_target()
# Out:
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Creating a new dataset in target
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening inputs for chunk (0,)
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray (0,): 'ftp://ftp.hycom.org/pub/xbxu/ATLc0.02/SWOT_ADAC/HYCOM50_E043_Feb_GE_daily.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'ftp://ftp.hycom.org/pub/xbxu/ATLc0.02/SWOT_ADAC/HYCOM50_E043_Feb_GE_daily.nc' from cache
# pangeo_forge_recipes.storage - DEBUG - file_opener entering first context for <contextlib._GeneratorContextManager object at 0x7f3348804bb0>
# pangeo_forge_recipes.storage - DEBUG - entering fs.open context manager for gs://pangeo-forge-us-central1/pangeo-forge-cache/swot_adac/HYCOM50/Region02_GE/int/fma/df4955281e33c8c39ad42fca01b0f13b-ftp_ftp.hycom.org_pub_xbxu_atlc0.02_swot_adac_hycom50_e043_feb_ge_daily.nc
# ...

# %% [markdown]
# #### Restart kernel, then restart recipe from `prepare_target`
#
# This seems to resolve the issue. I've `KeyboardInterrupt`ed the `store_chunk` step just to avoid writing the data.

# %%
from hycom_recipe import recipes as recipe_dict
from recipe_helpers import setup_logging, setup_targets

setup_logging()
rec = setup_targets(recipe_dict, key="HYCOM50/Region02_GE/int/fma")
# Out:
# Targets for recipe_dict["HYCOM50/Region02_GE/int/fma"] set to:
#
#     input_cache: gs://pangeo-forge-us-central1/pangeo-forge-cache/swot_adac/HYCOM50/Region02_GE/int/fma
#     metadata_cache: metadata/HYCOM50-Region02_GE-int-fma
#     target: zarr_build/HYCOM50-Region02_GE-int-fma.zarr

# %%
rec.prepare_target()
# Out:
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Creating a new dataset in target
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening inputs for chunk (0,)
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray (0,): 'ftp://ftp.hycom.org/pub/xbxu/ATLc0.02/SWOT_ADAC/HYCOM50_E043_Feb_GE_daily.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'ftp://ftp.hycom.org/pub/xbxu/ATLc0.02/SWOT_ADAC/HYCOM50_E043_Feb_GE_daily.nc' from cache
# pangeo_forge_recipes.storage - DEBUG - file_opener entering first context for <contextlib._GeneratorContextManager object at 0x7f4a6cfd6490>
# pangeo_forge_recipes.storage - DEBUG - entering fs.open context manager for gs://pangeo-forge-us-central1/pangeo-forge-cache/swot_adac/HYCOM50/Region02_GE/int/fma/df4955281e33c8c39ad42fca01b0f13b-ftp_ftp.hycom.org_pub_xbxu_atlc0.02_swot_adac_hycom50_e043_feb_ge_daily.nc
# ...

# %%
for chunk in rec.iter_chunks():
    rec.store_chunk(chunk)
# Out:
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening inputs for chunk (0,)
# pangeo_forge_recipes.recipes.xarray_zarr - INFO - Opening input with Xarray (0,): 'ftp://ftp.hycom.org/pub/xbxu/ATLc0.02/SWOT_ADAC/HYCOM50_E043_Feb_GE_daily.nc'
# pangeo_forge_recipes.storage - INFO - Opening 'ftp://ftp.hycom.org/pub/xbxu/ATLc0.02/SWOT_ADAC/HYCOM50_E043_Feb_GE_daily.nc' from cache
# pangeo_forge_recipes.storage - DEBUG - file_opener entering first context for <contextlib._GeneratorContextManager object at 0x7f4a6c767fa0>
# pangeo_forge_recipes.storage - DEBUG - entering fs.open context manager for gs://pangeo-forge-us-central1/pangeo-forge-cache/swot_adac/HYCOM50/Region02_GE/int/fma/df4955281e33c8c39ad42fca01b0f13b-ftp_ftp.hycom.org_pub_xbxu_atlc0.02_swot_adac_hycom50_e043_feb_ge_daily.nc
# ...
